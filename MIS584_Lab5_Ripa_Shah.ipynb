# %% [markdown]
# <a href="https://colab.research.google.com/github/Ripa-Shah/Big-Data-Technology/blob/main/MIS584_Lab5_Ripa_Shah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MIS584 Lab Assignment 5
# ## Learning Objectives
# * Demonstrate the capability of applying natural language processing in practice
#
# ## Due Date
# **Check D2L for the Due Dates**
#
# ## Assignment Submission Instructions
# When your file is ready, submit the following deliverables to the Lab Assignmen 5 dropbox:
# * Provide the link to your Google Colab notebook in the comments section; please make sure that **you enable the general access to your notebook with links before submission**. Failure to open your notebook will automatically lead to a grade of 0.
# * Upload the notebook file with the `.ipynb` suffix to the submission drop box. The uploaded notebook should have the same content as the one shared through the link, include enough documentation of the code, and have all the outputs available.
#
# ## Others
# As always, feel free to come to our office hours or let us know through email if you face any difficulties/challenges while finishing the assignment. Good luck! For your convenience, I have created the text and code cells you might need for the lab assignment. Please also complete your contact information in the notebook as well.

# %% [markdown]
# ## Student's Contact Information:
# Name: Ripa Shah
#
# Email: ripashah@arizona.edu

# %% [markdown]
# ## Part 0: Download SMS Spam Dataset
# For this lab assignment, we will be working with the [SMS Spam Dataset](https://archive.ics.uci.edu/ml/datasets/SMS+Spam+Collection) provided by the UCI machine learning repository.
#
# Fighting spams is a critical task for many mobile service providers. However, such a task is challenging because of the complexity of natural language. In this lab assignment, we will apply the natural language processing techniques discussed during the class meetings to build a classifier that can accurately predict whether an SMS text is a spam or not.
#
# For this lab assignment, you need to first download two text files, namely `spam-train.csv` and `spam-test.csv`. The `spam-train.txt` includes the text of multiple SMS messages as well as their labels (1 for spam and 0 for non-spam). The `spam-test.txt` includes text and labels for another set of SMS messages. Some example data points are listed as follows:
# ```
# label	text
# 0		Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1		FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, £1.50 to rcv
# 0		As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune
# 1		WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.
# 1		Had your mobile 11 months or more? U R entitled to Update to the latest colour mobiles with camera for Free! Call The Mobile Update Co FREE on 08002986030
#
# ```

# %%
from urllib.request import urlretrieve
urlretrieve('https://drive.google.com/uc?export=download&id=1NdiA8ZXLrIkdOo1xH3EPlp7HB8KMamck',
            'spam-train.csv')
urlretrieve('https://drive.google.com/uc?export=download&id=1cMEw3JICGb_lGhYz186jbr-rhExQ6RCE',
            'spam-test.csv')
# Out:
# ('spam-test.csv', <http.client.HTTPMessage at 0x79b3edad0a40>)

# %% [markdown]
# ## Part 1: Import Data (1.5 Point)
# In this section, you need to use **`pandas`** to import both `spam-train.csv` and `spam-test.csv`. Please create a DataFrame `spam_train` to store the data from `spam-train.csv` and create another DataFrame `spam_test` to store the data from `spam-test.csv`. Please also report how many SMS messages each csv file has.

# %%
"""
This code cell is for Lab Assignment 5 Part 1
"""
import pandas as pd
spam_train = pd.read_csv('spam-train.csv')
spam_test = pd.read_csv('spam-test.csv')
# Rename columns for clarity (v1 is label, v2 is text)
spam_train.columns = ['label', 'text']
spam_test.columns = ['label', 'text']

# 3. Report the number of messages
train_count = len(spam_train)
test_count = len(spam_test)

print("\n✅ Data Loading Complete.")
print(f"**spam-train.csv** has **{train_count}** SMS messages.")
print(f"**spam-test.csv** has **{test_count}** SMS messages.")
# Out:
# ✅ Data Loading Complete.
# **spam-train.csv** has **1600** SMS messages.
# **spam-test.csv** has **400** SMS messages.

# %% [markdown]
# ## Part 2.1: Preprocess Text Data (2 Point)
# In this section, you need to complete the code for preprocessing the SMS text data in both `spam-train.csv` and `spam-test.csv`. Specifically, the code should (1) tokenize each SMS text, (2) lowercase each token, (3) remove punctuations, (4) remove stop words, and (5) conduct stemming for each remaining token. Print the first 10 preprocessed SMS text messages in `spam-train.csv` and `spam-test.csv`, respectively.
#
# We have provided some example code below to help you get started. For this part, you only need to complete the code under the "TODO" comments, where the code needs to separately preprocess SMS messages for both `spam-train.csv` and `spam-test.csv`.

# %%
"""
This code cell is for Lab Assignment 5 Part 2
"""
train_msgs = spam_train.iloc[:, 1]
test_msgs = spam_test.iloc[:, 1]

## download the punkt module
import nltk
nltk.download('punkt')

## get punctuations
import string
punctuations = string.punctuation

## download stop words
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

## import stemmer
from nltk.stem import PorterStemmer
ps = PorterStemmer()


# --- Preprocessing Function ---
def preprocess_text(text):
    """Performs the 5 steps of preprocessing on a single text message string."""
    # (1) tokenize each SMS text
    tokens = nltk.word_tokenize(text)
    print("tokenize each SMS text", tokens)

    processed_tokens = []
    for token in tokens:
        # (2) lowercase each token
        token = token.lower()
        print("lowercase each token", token)

        # (3) remove punctuations (only remove if the token is *only* punctuation)
        if token not in punctuations:
            # (4) remove stop words
            if token not in stop_words:
                # (5) conduct stemming for each remaining token
                stemmed_token = ps.stem(token)
                processed_tokens.append(stemmed_token)
                print("conduct stemming for each remaining token", stemmed_token)
    # Rejoin the tokens into a single string
    return " ".join(processed_tokens)
## iteratively process each SMS message in spam-train.csv
# ## iteratively process each SMS message in spam-train.csv
new_train_msgs = []
for msg in train_msgs:
    ## TODO: insert your code here to process each message in the spam-train.csv
    processed_msg = preprocess_text(msg)
    new_train_msgs.append(processed_msg)


# ## iteratively process each SMS message in spam-test.csv
new_test_msgs = []
for msg in test_msgs:
    ## TODO: insert your code here to process each message in the spam-test.csv
    processed_msg = preprocess_text(msg)
    new_test_msgs.append(processed_msg)

print("\n--- First 10 Preprocessed SMS Messages (spam-train.csv) ---")
for i, msg in enumerate(new_train_msgs[:10]):
    # Assuming the original label is in spam_train.iloc[i, 0]
    label = spam_train.iloc[i, 0]
    print(f"({label}) Msg {i+1}: {msg}")

print("\n--- First 10 Preprocessed SMS Messages (spam-test.csv) ---")
for i, msg in enumerate(new_test_msgs[:10]):
    label = spam_test.iloc[i, 0]
    print(f"({label}) Msg {i+1}: {msg}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Streaming output truncated to the last 5000 lines.
# lowercase each token lesson
# conduct stemming for each remaining token lesson
# lowercase each token or
# lowercase each token gym
# conduct stemming for each remaining token gym
# lowercase each token ?
# tokenize each SMS text ['Ugh', '.', 'Got', 'ta', 'drive', 'back', 'to', 'sd', 'from', 'la', '.', 'My', 'butt', 'is', 'sore', '.']
# lowercase each token ugh
# conduct stemming for each remaining token ugh
# lowercase each token .
# lowercase each token got
# conduct stemming for each remaining token got
# lowercase each token ta
# conduct stemming for each remaining token ta
# lowercase each token drive
# conduct stemming for each remaining token drive
# lowercase each token back
# conduct stemming for each remaining token back
# lowercase each token to
# lowercase each token sd
# conduct stemming for each remaining token sd
# lowercase each token from
# lowercase each token la
# conduct stemming for each remaining token la
# lowercase each token .
# lowercase each token my
# lowercase each token butt
# conduct stemming for each remaining token butt
# lowercase each token is
# lowercase each token sore
# conduct stemming for each remaining token sore
# lowercase each token .
# tokenize each SMS text ['Ok', 'pa', '.', 'Nothing', 'problem', ':', '-', ')']
# lowercase each token ok
# conduct stemming for each remaining token ok
# lowercase each token pa
# conduct stemming for each remaining token pa
# lowercase each token .
# lowercase each token nothing
# conduct stemming for each remaining token noth
# lowercase each token problem
# conduct stemming for each remaining token problem
# lowercase each token :
# lowercase each token -
# lowercase each token )
# tokenize each SMS text ['Thank', 'you', '.', 'I', 'like', 'you', 'as', 'well', '...']
# lowercase each token thank
# conduct stemming for each remaining token thank
# lowercase each token you
# lowercase each token .
# lowercase each token i
# lowercase each token like
# conduct stemming for each remaining token like
# lowercase each token you
# lowercase each token as
# lowercase each token well
# conduct stemming for each remaining token well
# lowercase each token ...
# conduct stemming for each remaining token ...
# tokenize each SMS text ['Ugh', 'my', 'leg', 'hurts', '.', 'Musta', 'overdid', 'it', 'on', 'mon', '.']
# lowercase each token ugh
# conduct stemming for each remaining token ugh
# lowercase each token my
# lowercase each token leg
# conduct stemming for each remaining token leg
# lowercase each token hurts
# conduct stemming for each remaining token hurt
# lowercase each token .
# lowercase each token musta
# conduct stemming for each remaining token musta
# lowercase each token overdid
# conduct stemming for each remaining token overdid
# lowercase each token it
# lowercase each token on
# lowercase each token mon
# conduct stemming for each remaining token mon
# lowercase each token .
# tokenize each SMS text ['Forgot', 'you', 'were', 'working', 'today', '!', 'Wan', 'na', 'chat', ',', 'but', 'things', 'are', 'ok', 'so', 'drop', 'me', 'a', 'text', 'when', 'you', "'re", 'free', '/', 'bored', 'etc', 'and', 'i', "'ll", 'ring', '.', 'Hope', 'all', 'is', 'well', ',', 'nose', 'essay', 'and', 'all', 'xx']
# lowercase each token forgot
# conduct stemming for each remaining token forgot
# lowercase each token you
# lowercase each token were
# lowercase each token working
# conduct stemming for each remaining token work
# lowercase each token today
# conduct stemming for each remaining token today
# lowercase each token !
# lowercase each token wan
# conduct stemming for each remaining token wan
# lowercase each token na
# conduct stemming for each remaining token na
# lowercase each token chat
# conduct stemming for each remaining token chat
# lowercase each token ,
# lowercase each token but
# lowercase each token things
# conduct stemming for each remaining token thing
# lowercase each token are
# lowercase each token ok
# conduct stemming for each remaining token ok
# lowercase each token so
# lowercase each token drop
# conduct stemming for each remaining token drop
# lowercase each token me
# lowercase each token a
# lowercase each token text
# conduct stemming for each remaining token text
# lowercase each token when
# lowercase each token you
# lowercase each token 're
# conduct stemming for each remaining token 're
# lowercase each token free
# conduct stemming for each remaining token free
# lowercase each token /
# lowercase each token bored
# conduct stemming for each remaining token bore
# lowercase each token etc
# conduct stemming for each remaining token etc
# lowercase each token and
# lowercase each token i
# lowercase each token 'll
# conduct stemming for each remaining token 'll
# lowercase each token ring
# conduct stemming for each remaining token ring
# lowercase each token .
# lowercase each token hope
# conduct stemming for each remaining token hope
# lowercase each token all
# lowercase each token is
# lowercase each token well
# conduct stemming for each remaining token well
# lowercase each token ,
# lowercase each token nose
# conduct stemming for each remaining token nose
# lowercase each token essay
# conduct stemming for each remaining token essay
# lowercase each token and
# lowercase each token all
# lowercase each token xx
# conduct stemming for each remaining token xx
# tokenize each SMS text ['Ok', 'but', 'knackered', '.', 'Just', 'came', 'home', 'and', 'went', 'to', 'sleep', '!', 'Not', 'good', 'at', 'this', 'full', 'time', 'work', 'lark', '.']
# lowercase each token ok
# conduct stemming for each remaining token ok
# lowercase each token but
# lowercase each token knackered
# conduct stemming for each remaining token knacker
# lowercase each token .
# lowercase each token just
# lowercase each token came
# conduct stemming for each remaining token came
# lowercase each token home
# conduct stemming for each remaining token home
# lowercase each token and
# lowercase each token went
# conduct stemming for each remaining token went
# lowercase each token to
# lowercase each token sleep
# conduct stemming for each remaining token sleep
# lowercase each token !
# lowercase each token not
# lowercase each token good
# conduct stemming for each remaining token good
# lowercase each token at
# lowercase each token this
# lowercase each token full
# conduct stemming for each remaining token full
# lowercase each token time
# conduct stemming for each remaining token time
# lowercase each token work
# conduct stemming for each remaining token work
# lowercase each token lark
# conduct stemming for each remaining token lark
# lowercase each token .
# tokenize each SMS text ['It', "'s", 'that', 'time', 'of', 'the', 'week', 'again', ',', 'ryan']
# lowercase each token it
# lowercase each token 's
# conduct stemming for each remaining token 's
# lowercase each token that
# lowercase each token time
# conduct stemming for each remaining token time
# lowercase each token of
# lowercase each token the
# lowercase each token week
# conduct stemming for each remaining token week
# lowercase each token again
# lowercase each token ,
# lowercase each token ryan
# conduct stemming for each remaining token ryan
# tokenize each SMS text ['Dunno', 'lei', '...', 'I', 'might', 'b', 'eatin', 'wif', 'my', 'frens', '...', 'If', 'ü', 'wan', 'to', 'eat', 'then', 'i', 'wait', '4', 'ü', 'lar']
# lowercase each token dunno
# conduct stemming for each remaining token dunno
# lowercase each token lei
# conduct stemming for each remaining token lei
# lowercase each token ...
# conduct stemming for each remaining token ...
# lowercase each token i
# lowercase each token might
# conduct stemming for each remaining token might
# lowercase each token b
# conduct stemming for each remaining token b
# lowercase each token eatin
# conduct stemming for each remaining token eatin
# lowercase each token wif
# conduct stemming for each remaining token wif
# lowercase each token my
# lowercase each token frens
# conduct stemming for each remaining token fren
# lowercase each token ...
# conduct stemming for each remaining token ...
# lowercase each token if
# lowercase each token ü
# conduct stemming for each remaining token ü
# lowercase each token wan
# conduct stemming for each remaining token wan
# lowercase each token to
# lowercase each token eat
# conduct stemming for each remaining token eat
# lowercase each token then
# lowercase each token i
# lowercase each token wait
# conduct stemming for each remaining token wait
# lowercase each token 4
# conduct stemming for each remaining token 4
# lowercase each token ü
# conduct stemming for each remaining token ü
# lowercase each token lar
# conduct stemming for each remaining token lar
# tokenize each SMS text ['Oh', '...', 'I', 'was', 'thkin', 'of', 'goin', 'yogasana', 'at', '10', 'den', 'no', 'nd', 'to', 'go', 'at', '3', 'den', 'can', 'rush', 'to', 'parco', '4', 'nb', '...', 'Okie', 'lor', ',', 'u', 'call', 'me', 'when', 'ready', '...']
# lowercase each token oh
# conduct stemming for each remaining token oh
# lowercase each token ...
# conduct stemming for each remaining token ...
# lowercase each token i
# lowercase each token was
# lowercase each token thkin
# conduct stemming for each remaining token thkin
# lowercase each token of
# lowercase each token goin
# conduct stemming for each remaining token goin
# lowercase each token yogasana
# conduct stemming for each remaining token yogasana
# lowercase each token at
# lowercase each token 10
# conduct stemming for each remaining token 10
# lowercase each token den
# conduct stemming for each remaining token den
# lowercase each token no
# lowercase each token nd
# conduct stemming for each remaining token nd
# lowercase each token to
# lowercase each token go
# conduct stemming for each remaining token go
# lowercase each token at
# lowercase each token 3
# conduct stemming for each remaining token 3
# lowercase each token den
# conduct stemming for each remaining token den
# lowercase each token can
# lowercase each token rush
# conduct stemming for each remaining token rush
# lowercase each token to
# lowercase each token parco
# conduct stemming for each remaining token parco
# lowercase each token 4
# conduct stemming for each remaining token 4
# lowercase each token nb
# conduct stemming for each remaining token nb
# lowercase each token ...
# conduct stemming for each remaining token ...
# lowercase each token okie
# conduct stemming for each remaining token oki
# lowercase each token lor
# conduct stemming for each remaining token lor
# lowercase each token ,
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token call
# conduct stemming for each remaining token call
# lowercase each token me
# lowercase each token when
# lowercase each token ready
# conduct stemming for each remaining token readi
# lowercase each token ...
# conduct stemming for each remaining token ...
# tokenize each SMS text ['I', "'m", 'in', 'class', '.', 'Will', 'holla', 'later']
# lowercase each token i
# lowercase each token 'm
# conduct stemming for each remaining token 'm
# lowercase each token in
# lowercase each token class
# conduct stemming for each remaining token class
# lowercase each token .
# lowercase each token will
# lowercase each token holla
# conduct stemming for each remaining token holla
# lowercase each token later
# conduct stemming for each remaining token later
# tokenize each SMS text ['Welcome', '!', 'Please', 'reply', 'with', 'your', 'AGE', 'and', 'GENDER', 'to', 'begin', '.', 'e.g', '24M']
# lowercase each token welcome
# conduct stemming for each remaining token welcom
# lowercase each token !
# lowercase each token please
# conduct stemming for each remaining token pleas
# lowercase each token reply
# conduct stemming for each remaining token repli
# lowercase each token with
# lowercase each token your
# lowercase each token age
# conduct stemming for each remaining token age
# lowercase each token and
# lowercase each token gender
# conduct stemming for each remaining token gender
# lowercase each token to
# lowercase each token begin
# conduct stemming for each remaining token begin
# lowercase each token .
# lowercase each token e.g
# conduct stemming for each remaining token e.g
# lowercase each token 24m
# conduct stemming for each remaining token 24m
# tokenize each SMS text ['Helloooo', '...', 'Wake', 'up', '..', '!', '``', 'Sweet', "''", '``', 'morning', "''", '``', 'welcomes', "''", '``', 'You', "''", '``', 'Enjoy', "''", '``', 'This', 'Day', "''", '``', 'with', 'full', 'of', 'joy', "''", '..', '``', 'GUD', 'MRNG', "''", '.']
# lowercase each token helloooo
# conduct stemming for each remaining token helloooo
# lowercase each token ...
# conduct stemming for each remaining token ...
# lowercase each token wake
# conduct stemming for each remaining token wake
# lowercase each token up
# lowercase each token ..
# conduct stemming for each remaining token ..
# lowercase each token !
# lowercase each token ``
# conduct stemming for each remaining token ``
# lowercase each token sweet
# conduct stemming for each remaining token sweet
# lowercase each token ''
# conduct stemming for each remaining token ''
# lowercase each token ``
# conduct stemming for each remaining token ``
# lowercase each token morning
# conduct stemming for each remaining token morn
# lowercase each token ''
# conduct stemming for each remaining token ''
# lowercase each token ``
# conduct stemming for each remaining token ``
# lowercase each token welcomes
# conduct stemming for each remaining token welcom
# lowercase each token ''
# conduct stemming for each remaining token ''
# lowercase each token ``
# conduct stemming for each remaining token ``
# lowercase each token you
# lowercase each token ''
# conduct stemming for each remaining token ''
# lowercase each token ``
# conduct stemming for each remaining token ``
# lowercase each token enjoy
# conduct stemming for each remaining token enjoy
# lowercase each token ''
# conduct stemming for each remaining token ''
# lowercase each token ``
# conduct stemming for each remaining token ``
# lowercase each token this
# lowercase each token day
# conduct stemming for each remaining token day
# lowercase each token ''
# conduct stemming for each remaining token ''
# lowercase each token ``
# conduct stemming for each remaining token ``
# lowercase each token with
# lowercase each token full
# conduct stemming for each remaining token full
# lowercase each token of
# lowercase each token joy
# conduct stemming for each remaining token joy
# lowercase each token ''
# conduct stemming for each remaining token ''
# lowercase each token ..
# conduct stemming for each remaining token ..
# lowercase each token ``
# conduct stemming for each remaining token ``
# lowercase each token gud
# conduct stemming for each remaining token gud
# lowercase each token mrng
# conduct stemming for each remaining token mrng
# lowercase each token ''
# conduct stemming for each remaining token ''
# lowercase each token .
# tokenize each SMS text ['You', 'have', 'registered', 'Sinco', 'as', 'Payee', '.', 'Log', 'in', 'at', 'icicibank.com', 'and', 'enter', 'URN', '&', 'lt', ';', '#', '&', 'gt', ';', 'to', 'confirm', '.', 'Beware', 'of', 'frauds', '.', 'Do', 'NOT', 'share', 'or', 'disclose', 'URN', 'to', 'anyone', '.']
# lowercase each token you
# lowercase each token have
# lowercase each token registered
# conduct stemming for each remaining token regist
# lowercase each token sinco
# conduct stemming for each remaining token sinco
# lowercase each token as
# lowercase each token payee
# conduct stemming for each remaining token paye
# lowercase each token .
# lowercase each token log
# conduct stemming for each remaining token log
# lowercase each token in
# lowercase each token at
# lowercase each token icicibank.com
# conduct stemming for each remaining token icicibank.com
# lowercase each token and
# lowercase each token enter
# conduct stemming for each remaining token enter
# lowercase each token urn
# conduct stemming for each remaining token urn
# lowercase each token &
# lowercase each token lt
# conduct stemming for each remaining token lt
# lowercase each token ;
# lowercase each token #
# lowercase each token &
# lowercase each token gt
# conduct stemming for each remaining token gt
# lowercase each token ;
# lowercase each token to
# lowercase each token confirm
# conduct stemming for each remaining token confirm
# lowercase each token .
# lowercase each token beware
# conduct stemming for each remaining token bewar
# lowercase each token of
# lowercase each token frauds
# conduct stemming for each remaining token fraud
# lowercase each token .
# lowercase each token do
# lowercase each token not
# lowercase each token share
# conduct stemming for each remaining token share
# lowercase each token or
# lowercase each token disclose
# conduct stemming for each remaining token disclos
# lowercase each token urn
# conduct stemming for each remaining token urn
# lowercase each token to
# lowercase each token anyone
# conduct stemming for each remaining token anyon
# lowercase each token .
# tokenize each SMS text ['Ok', '.', 'So', 'april', '.', 'Cant', 'wait']
# lowercase each token ok
# conduct stemming for each remaining token ok
# lowercase each token .
# lowercase each token so
# lowercase each token april
# conduct stemming for each remaining token april
# lowercase each token .
# lowercase each token cant
# conduct stemming for each remaining token cant
# lowercase each token wait
# conduct stemming for each remaining token wait
# tokenize each SMS text ['U', 'have', 'a', 'Secret', 'Admirer', 'who', 'is', 'looking', '2', 'make', 'contact', 'with', 'U-find', 'out', 'who', 'they', 'R', '*', 'reveal', 'who', 'thinks', 'UR', 'so', 'special-call', 'on', '09065171142-stopsms-08']
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token have
# lowercase each token a
# lowercase each token secret
# conduct stemming for each remaining token secret
# lowercase each token admirer
# conduct stemming for each remaining token admir
# lowercase each token who
# lowercase each token is
# lowercase each token looking
# conduct stemming for each remaining token look
# lowercase each token 2
# conduct stemming for each remaining token 2
# lowercase each token make
# conduct stemming for each remaining token make
# lowercase each token contact
# conduct stemming for each remaining token contact
# lowercase each token with
# lowercase each token u-find
# conduct stemming for each remaining token u-find
# lowercase each token out
# lowercase each token who
# lowercase each token they
# lowercase each token r
# conduct stemming for each remaining token r
# lowercase each token *
# lowercase each token reveal
# conduct stemming for each remaining token reveal
# lowercase each token who
# lowercase each token thinks
# conduct stemming for each remaining token think
# lowercase each token ur
# conduct stemming for each remaining token ur
# lowercase each token so
# lowercase each token special-call
# conduct stemming for each remaining token special-cal
# lowercase each token on
# lowercase each token 09065171142-stopsms-08
# conduct stemming for each remaining token 09065171142-stopsms-08
# tokenize each SMS text ['Joy', "'s", 'father', 'is', 'John', '.', 'Then', 'John', 'is', 'the', 'NAME', 'of', 'Joy', "'s", 'father', '.', 'Mandan']
# lowercase each token joy
# conduct stemming for each remaining token joy
# lowercase each token 's
# conduct stemming for each remaining token 's
# lowercase each token father
# conduct stemming for each remaining token father
# lowercase each token is
# lowercase each token john
# conduct stemming for each remaining token john
# lowercase each token .
# lowercase each token then
# lowercase each token john
# conduct stemming for each remaining token john
# lowercase each token is
# lowercase each token the
# lowercase each token name
# conduct stemming for each remaining token name
# lowercase each token of
# lowercase each token joy
# conduct stemming for each remaining token joy
# lowercase each token 's
# conduct stemming for each remaining token 's
# lowercase each token father
# conduct stemming for each remaining token father
# lowercase each token .
# lowercase each token mandan
# conduct stemming for each remaining token mandan
# tokenize each SMS text ['Change', 'again', '...', 'It', "'s", 'e', 'one', 'next', 'to', 'escalator', '...']
# lowercase each token change
# conduct stemming for each remaining token chang
# lowercase each token again
# lowercase each token ...
# conduct stemming for each remaining token ...
# lowercase each token it
# lowercase each token 's
# conduct stemming for each remaining token 's
# lowercase each token e
# conduct stemming for each remaining token e
# lowercase each token one
# conduct stemming for each remaining token one
# lowercase each token next
# conduct stemming for each remaining token next
# lowercase each token to
# lowercase each token escalator
# conduct stemming for each remaining token escal
# lowercase each token ...
# conduct stemming for each remaining token ...
# tokenize each SMS text ['HI', 'DARLIN', 'I', 'HOPE', 'YOU', 'HAD', 'A', 'NICE', 'NIGHT', 'I', 'WISH', 'I', 'HAD', 'COME', 'CANT', 'WAIT', 'TO', 'SEE', 'YOU', 'LOVE', 'FRAN', 'PS', 'I', 'WANT', 'DIRTY', 'ANAL', 'SEX', 'AND', 'I', 'WANT', 'A', '10', 'MAN', 'GANG', 'BANG']
# lowercase each token hi
# conduct stemming for each remaining token hi
# lowercase each token darlin
# conduct stemming for each remaining token darlin
# lowercase each token i
# lowercase each token hope
# conduct stemming for each remaining token hope
# lowercase each token you
# lowercase each token had
# lowercase each token a
# lowercase each token nice
# conduct stemming for each remaining token nice
# lowercase each token night
# conduct stemming for each remaining token night
# lowercase each token i
# lowercase each token wish
# conduct stemming for each remaining token wish
# lowercase each token i
# lowercase each token had
# lowercase each token come
# conduct stemming for each remaining token come
# lowercase each token cant
# conduct stemming for each remaining token cant
# lowercase each token wait
# conduct stemming for each remaining token wait
# lowercase each token to
# lowercase each token see
# conduct stemming for each remaining token see
# lowercase each token you
# lowercase each token love
# conduct stemming for each remaining token love
# lowercase each token fran
# conduct stemming for each remaining token fran
# lowercase each token ps
# conduct stemming for each remaining token ps
# lowercase each token i
# lowercase each token want
# conduct stemming for each remaining token want
# lowercase each token dirty
# conduct stemming for each remaining token dirti
# lowercase each token anal
# conduct stemming for each remaining token anal
# lowercase each token sex
# conduct stemming for each remaining token sex
# lowercase each token and
# lowercase each token i
# lowercase each token want
# conduct stemming for each remaining token want
# lowercase each token a
# lowercase each token 10
# conduct stemming for each remaining token 10
# lowercase each token man
# conduct stemming for each remaining token man
# lowercase each token gang
# conduct stemming for each remaining token gang
# lowercase each token bang
# conduct stemming for each remaining token bang
# tokenize each SMS text ['Wot', 'u', 'up', '2', '?', 'Thout', 'u', 'were', 'gon', 'na', 'call', 'me', '!', '!', 'Txt', 'bak', 'luv', 'K']
# lowercase each token wot
# conduct stemming for each remaining token wot
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token up
# lowercase each token 2
# conduct stemming for each remaining token 2
# lowercase each token ?
# lowercase each token thout
# conduct stemming for each remaining token thout
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token were
# lowercase each token gon
# conduct stemming for each remaining token gon
# lowercase each token na
# conduct stemming for each remaining token na
# lowercase each token call
# conduct stemming for each remaining token call
# lowercase each token me
# lowercase each token !
# lowercase each token !
# lowercase each token txt
# conduct stemming for each remaining token txt
# lowercase each token bak
# conduct stemming for each remaining token bak
# lowercase each token luv
# conduct stemming for each remaining token luv
# lowercase each token k
# conduct stemming for each remaining token k
# tokenize each SMS text ['Call', 'from', '08702490080', '-', 'tells', 'u', '2', 'call', '09066358152', 'to', 'claim', '£5000', 'prize', '.', 'U', 'have', '2', 'enter', 'all', 'ur', 'mobile', '&', 'personal', 'details', '@', 'the', 'prompts', '.', 'Careful', '!']
# lowercase each token call
# conduct stemming for each remaining token call
# lowercase each token from
# lowercase each token 08702490080
# conduct stemming for each remaining token 08702490080
# lowercase each token -
# lowercase each token tells
# conduct stemming for each remaining token tell
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token 2
# conduct stemming for each remaining token 2
# lowercase each token call
# conduct stemming for each remaining token call
# lowercase each token 09066358152
# conduct stemming for each remaining token 09066358152
# lowercase each token to
# lowercase each token claim
# conduct stemming for each remaining token claim
# lowercase each token £5000
# conduct stemming for each remaining token £5000
# lowercase each token prize
# conduct stemming for each remaining token prize
# lowercase each token .
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token have
# lowercase each token 2
# conduct stemming for each remaining token 2
# lowercase each token enter
# conduct stemming for each remaining token enter
# lowercase each token all
# lowercase each token ur
# conduct stemming for each remaining token ur
# lowercase each token mobile
# conduct stemming for each remaining token mobil
# lowercase each token &
# lowercase each token personal
# conduct stemming for each remaining token person
# lowercase each token details
# conduct stemming for each remaining token detail
# lowercase each token @
# lowercase each token the
# lowercase each token prompts
# conduct stemming for each remaining token prompt
# lowercase each token .
# lowercase each token careful
# conduct stemming for each remaining token care
# lowercase each token !
# tokenize each SMS text ['Fyi', 'I', "'m", 'taking', 'a', 'quick', 'shower', ',', 'be', 'at', 'epsilon', 'in', 'like', '&', 'lt', ';', '#', '&', 'gt', ';', 'min']
# lowercase each token fyi
# conduct stemming for each remaining token fyi
# lowercase each token i
# lowercase each token 'm
# conduct stemming for each remaining token 'm
# lowercase each token taking
# conduct stemming for each remaining token take
# lowercase each token a
# lowercase each token quick
# conduct stemming for each remaining token quick
# lowercase each token shower
# conduct stemming for each remaining token shower
# lowercase each token ,
# lowercase each token be
# lowercase each token at
# lowercase each token epsilon
# conduct stemming for each remaining token epsilon
# lowercase each token in
# lowercase each token like
# conduct stemming for each remaining token like
# lowercase each token &
# lowercase each token lt
# conduct stemming for each remaining token lt
# lowercase each token ;
# lowercase each token #
# lowercase each token &
# lowercase each token gt
# conduct stemming for each remaining token gt
# lowercase each token ;
# lowercase each token min
# conduct stemming for each remaining token min
# tokenize each SMS text ['I', 'wud', 'never', 'mind', 'if', 'u', 'dont', 'miss', 'me', 'or', 'if', 'u', 'dont', 'need', 'me', '..', 'But', 'u', 'wil', 'really', 'hurt', 'me', 'wen', 'u', 'need', 'me', '&', 'amp', ';', 'u', 'dont', 'tell', 'me', '.........', 'Take', 'care', ':', '-', ')']
# lowercase each token i
# lowercase each token wud
# conduct stemming for each remaining token wud
# lowercase each token never
# conduct stemming for each remaining token never
# lowercase each token mind
# conduct stemming for each remaining token mind
# lowercase each token if
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token dont
# conduct stemming for each remaining token dont
# lowercase each token miss
# conduct stemming for each remaining token miss
# lowercase each token me
# lowercase each token or
# lowercase each token if
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token dont
# conduct stemming for each remaining token dont
# lowercase each token need
# conduct stemming for each remaining token need
# lowercase each token me
# lowercase each token ..
# conduct stemming for each remaining token ..
# lowercase each token but
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token wil
# conduct stemming for each remaining token wil
# lowercase each token really
# conduct stemming for each remaining token realli
# lowercase each token hurt
# conduct stemming for each remaining token hurt
# lowercase each token me
# lowercase each token wen
# conduct stemming for each remaining token wen
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token need
# conduct stemming for each remaining token need
# lowercase each token me
# lowercase each token &
# lowercase each token amp
# conduct stemming for each remaining token amp
# lowercase each token ;
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token dont
# conduct stemming for each remaining token dont
# lowercase each token tell
# conduct stemming for each remaining token tell
# lowercase each token me
# lowercase each token .........
# conduct stemming for each remaining token .........
# lowercase each token take
# conduct stemming for each remaining token take
# lowercase each token care
# conduct stemming for each remaining token care
# lowercase each token :
# lowercase each token -
# lowercase each token )
# tokenize each SMS text ['I', 'don', ',', 't', 'think', 'so', '.', 'You', 'do', "n't", 'need', 'to', 'be', 'going', 'out', 'that', 'late', 'on', 'a', 'school', 'night', '.', 'ESPECIALLY', 'when', 'the', 'one', 'class', 'you', 'have', 'is', 'the', 'one', 'you', 'missed', 'last', 'wednesday', 'and', 'probably', 'failed', 'a', 'test', 'in', 'on', 'friday']
# lowercase each token i
# lowercase each token don
# lowercase each token ,
# lowercase each token t
# lowercase each token think
# conduct stemming for each remaining token think
# lowercase each token so
# lowercase each token .
# lowercase each token you
# lowercase each token do
# lowercase each token n't
# conduct stemming for each remaining token n't
# lowercase each token need
# conduct stemming for each remaining token need
# lowercase each token to
# lowercase each token be
# lowercase each token going
# conduct stemming for each remaining token go
# lowercase each token out
# lowercase each token that
# lowercase each token late
# conduct stemming for each remaining token late
# lowercase each token on
# lowercase each token a
# lowercase each token school
# conduct stemming for each remaining token school
# lowercase each token night
# conduct stemming for each remaining token night
# lowercase each token .
# lowercase each token especially
# conduct stemming for each remaining token especi
# lowercase each token when
# lowercase each token the
# lowercase each token one
# conduct stemming for each remaining token one
# lowercase each token class
# conduct stemming for each remaining token class
# lowercase each token you
# lowercase each token have
# lowercase each token is
# lowercase each token the
# lowercase each token one
# conduct stemming for each remaining token one
# lowercase each token you
# lowercase each token missed
# conduct stemming for each remaining token miss
# lowercase each token last
# conduct stemming for each remaining token last
# lowercase each token wednesday
# conduct stemming for each remaining token wednesday
# lowercase each token and
# lowercase each token probably
# conduct stemming for each remaining token probabl
# lowercase each token failed
# conduct stemming for each remaining token fail
# lowercase each token a
# lowercase each token test
# conduct stemming for each remaining token test
# lowercase each token in
# lowercase each token on
# lowercase each token friday
# conduct stemming for each remaining token friday
# tokenize each SMS text ['U', 'GOIN', 'OUT', '2NITE', '?']
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token goin
# conduct stemming for each remaining token goin
# lowercase each token out
# lowercase each token 2nite
# conduct stemming for each remaining token 2nite
# lowercase each token ?
# tokenize each SMS text ['Nah', 'man', ',', 'my', 'car', 'is', 'meant', 'to', 'be', 'crammed', 'full', 'of', 'people']
# lowercase each token nah
# conduct stemming for each remaining token nah
# lowercase each token man
# conduct stemming for each remaining token man
# lowercase each token ,
# lowercase each token my
# lowercase each token car
# conduct stemming for each remaining token car
# lowercase each token is
# lowercase each token meant
# conduct stemming for each remaining token meant
# lowercase each token to
# lowercase each token be
# lowercase each token crammed
# conduct stemming for each remaining token cram
# lowercase each token full
# conduct stemming for each remaining token full
# lowercase each token of
# lowercase each token people
# conduct stemming for each remaining token peopl
# tokenize each SMS text ['I', 'dont', 'have', 'any', 'of', 'your', 'file', 'in', 'my', 'bag', '..', 'i', 'was', 'in', 'work', 'when', 'you', 'called', 'me.i', "'ll", 'tell', 'you', 'if', 'i', 'find', 'anything', 'in', 'my', 'room', '.']
# lowercase each token i
# lowercase each token dont
# conduct stemming for each remaining token dont
# lowercase each token have
# lowercase each token any
# lowercase each token of
# lowercase each token your
# lowercase each token file
# conduct stemming for each remaining token file
# lowercase each token in
# lowercase each token my
# lowercase each token bag
# conduct stemming for each remaining token bag
# lowercase each token ..
# conduct stemming for each remaining token ..
# lowercase each token i
# lowercase each token was
# lowercase each token in
# lowercase each token work
# conduct stemming for each remaining token work
# lowercase each token when
# lowercase each token you
# lowercase each token called
# conduct stemming for each remaining token call
# lowercase each token me.i
# conduct stemming for each remaining token me.i
# lowercase each token 'll
# conduct stemming for each remaining token 'll
# lowercase each token tell
# conduct stemming for each remaining token tell
# lowercase each token you
# lowercase each token if
# lowercase each token i
# lowercase each token find
# conduct stemming for each remaining token find
# lowercase each token anything
# conduct stemming for each remaining token anyth
# lowercase each token in
# lowercase each token my
# lowercase each token room
# conduct stemming for each remaining token room
# lowercase each token .
# tokenize each SMS text ['Morning', 'only', 'i', 'can', 'ok', '.']
# lowercase each token morning
# conduct stemming for each remaining token morn
# lowercase each token only
# lowercase each token i
# lowercase each token can
# lowercase each token ok
# conduct stemming for each remaining token ok
# lowercase each token .
# tokenize each SMS text ['hope', 'things', 'went', 'well', 'at', "'doctors", "'", ';', ')', 'reminds', 'me', 'i', 'still', 'need', '2go.did', 'u', 'c', 'd', 'little', 'thing', 'i', 'left', 'in', 'the', 'lounge', '?']
# lowercase each token hope
# conduct stemming for each remaining token hope
# lowercase each token things
# conduct stemming for each remaining token thing
# lowercase each token went
# conduct stemming for each remaining token went
# lowercase each token well
# conduct stemming for each remaining token well
# lowercase each token at
# lowercase each token 'doctors
# conduct stemming for each remaining token 'doctor
# lowercase each token '
# lowercase each token ;
# lowercase each token )
# lowercase each token reminds
# conduct stemming for each remaining token remind
# lowercase each token me
# lowercase each token i
# lowercase each token still
# conduct stemming for each remaining token still
# lowercase each token need
# conduct stemming for each remaining token need
# lowercase each token 2go.did
# conduct stemming for each remaining token 2go.did
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token c
# conduct stemming for each remaining token c
# lowercase each token d
# lowercase each token little
# conduct stemming for each remaining token littl
# lowercase each token thing
# conduct stemming for each remaining token thing
# lowercase each token i
# lowercase each token left
# conduct stemming for each remaining token left
# lowercase each token in
# lowercase each token the
# lowercase each token lounge
# conduct stemming for each remaining token loung
# lowercase each token ?
# tokenize each SMS text ['Easy', 'ah', '?', 'sen', 'got', 'selected', 'means', 'its', 'good', '..']
# lowercase each token easy
# conduct stemming for each remaining token easi
# lowercase each token ah
# conduct stemming for each remaining token ah
# lowercase each token ?
# lowercase each token sen
# conduct stemming for each remaining token sen
# lowercase each token got
# conduct stemming for each remaining token got
# lowercase each token selected
# conduct stemming for each remaining token select
# lowercase each token means
# conduct stemming for each remaining token mean
# lowercase each token its
# lowercase each token good
# conduct stemming for each remaining token good
# lowercase each token ..
# conduct stemming for each remaining token ..
# tokenize each SMS text ['Hard', 'LIVE', '121', 'chat', 'just', '60p/min', '.', 'Choose', 'your', 'girl', 'and', 'connect', 'LIVE', '.', 'Call', '09094646899', 'now', '!', 'Cheap', 'Chat', 'UK', "'s", 'biggest', 'live', 'service', '.', 'VU', 'BCM1896WC1N3XX']
# lowercase each token hard
# conduct stemming for each remaining token hard
# lowercase each token live
# conduct stemming for each remaining token live
# lowercase each token 121
# conduct stemming for each remaining token 121
# lowercase each token chat
# conduct stemming for each remaining token chat
# lowercase each token just
# lowercase each token 60p/min
# conduct stemming for each remaining token 60p/min
# lowercase each token .
# lowercase each token choose
# conduct stemming for each remaining token choos
# lowercase each token your
# lowercase each token girl
# conduct stemming for each remaining token girl
# lowercase each token and
# lowercase each token connect
# conduct stemming for each remaining token connect
# lowercase each token live
# conduct stemming for each remaining token live
# lowercase each token .
# lowercase each token call
# conduct stemming for each remaining token call
# lowercase each token 09094646899
# conduct stemming for each remaining token 09094646899
# lowercase each token now
# lowercase each token !
# lowercase each token cheap
# conduct stemming for each remaining token cheap
# lowercase each token chat
# conduct stemming for each remaining token chat
# lowercase each token uk
# conduct stemming for each remaining token uk
# lowercase each token 's
# conduct stemming for each remaining token 's
# lowercase each token biggest
# conduct stemming for each remaining token biggest
# lowercase each token live
# conduct stemming for each remaining token live
# lowercase each token service
# conduct stemming for each remaining token servic
# lowercase each token .
# lowercase each token vu
# conduct stemming for each remaining token vu
# lowercase each token bcm1896wc1n3xx
# conduct stemming for each remaining token bcm1896wc1n3xx
# tokenize each SMS text ['Yun', 'buying', '...', 'But', 'school', 'got', 'offer', '2000', 'plus', 'only', '...']
# lowercase each token yun
# conduct stemming for each remaining token yun
# lowercase each token buying
# conduct stemming for each remaining token buy
# lowercase each token ...
# conduct stemming for each remaining token ...
# lowercase each token but
# lowercase each token school
# conduct stemming for each remaining token school
# lowercase each token got
# conduct stemming for each remaining token got
# lowercase each token offer
# conduct stemming for each remaining token offer
# lowercase each token 2000
# conduct stemming for each remaining token 2000
# lowercase each token plus
# conduct stemming for each remaining token plu
# lowercase each token only
# lowercase each token ...
# conduct stemming for each remaining token ...
# tokenize each SMS text ['Lol', 'please', 'do', '.', 'Actually', 'send', 'a', 'pic', 'of', 'yourself', 'right', 'now', '.', 'I', 'wan', 'na', 'see', '.', 'Pose', 'with', 'a', 'comb', 'and', 'hair', 'dryer', 'or', 'something', '.']
# lowercase each token lol
# conduct stemming for each remaining token lol
# lowercase each token please
# conduct stemming for each remaining token pleas
# lowercase each token do
# lowercase each token .
# lowercase each token actually
# conduct stemming for each remaining token actual
# lowercase each token send
# conduct stemming for each remaining token send
# lowercase each token a
# lowercase each token pic
# conduct stemming for each remaining token pic
# lowercase each token of
# lowercase each token yourself
# lowercase each token right
# conduct stemming for each remaining token right
# lowercase each token now
# lowercase each token .
# lowercase each token i
# lowercase each token wan
# conduct stemming for each remaining token wan
# lowercase each token na
# conduct stemming for each remaining token na
# lowercase each token see
# conduct stemming for each remaining token see
# lowercase each token .
# lowercase each token pose
# conduct stemming for each remaining token pose
# lowercase each token with
# lowercase each token a
# lowercase each token comb
# conduct stemming for each remaining token comb
# lowercase each token and
# lowercase each token hair
# conduct stemming for each remaining token hair
# lowercase each token dryer
# conduct stemming for each remaining token dryer
# lowercase each token or
# lowercase each token something
# conduct stemming for each remaining token someth
# lowercase each token .
# tokenize each SMS text ['Watching', 'cartoon', ',', 'listening', 'music', '&', 'amp', ';', 'at', 'eve', 'had', 'to', 'go', 'temple', '&', 'amp', ';', 'church', '..', 'What', 'about', 'u', '?']
# lowercase each token watching
# conduct stemming for each remaining token watch
# lowercase each token cartoon
# conduct stemming for each remaining token cartoon
# lowercase each token ,
# lowercase each token listening
# conduct stemming for each remaining token listen
# lowercase each token music
# conduct stemming for each remaining token music
# lowercase each token &
# lowercase each token amp
# conduct stemming for each remaining token amp
# lowercase each token ;
# lowercase each token at
# lowercase each token eve
# conduct stemming for each remaining token eve
# lowercase each token had
# lowercase each token to
# lowercase each token go
# conduct stemming for each remaining token go
# lowercase each token temple
# conduct stemming for each remaining token templ
# lowercase each token &
# lowercase each token amp
# conduct stemming for each remaining token amp
# lowercase each token ;
# lowercase each token church
# conduct stemming for each remaining token church
# lowercase each token ..
# conduct stemming for each remaining token ..
# lowercase each token what
# lowercase each token about
# lowercase each token u
# conduct stemming for each remaining token u
# lowercase each token ?
# tokenize each SMS text ['We', 'have', 'new', 'local', 'dates', 'in', 'your', 'area', '-', 'Lots', 'of', 'new', 'people', 'registered', 'in', 'YOUR', 'AREA', '.', 'Reply', 'DATE', 'to', 'start', 'now', '!', '18', 'only', 'www.flirtparty.us', 'REPLYS150']
# lowercase each token we
# lowercase each token have
# lowercase each token new
# conduct stemming for each remaining token new
# lowercase each token local
# conduct stemming for each remaining token local
# lowercase each token dates
# conduct stemming for each remaining token date
# lowercase each token in
# lowercase each token your
# lowercase each token area
# conduct stemming for each remaining token area
# lowercase each token -
# lowercase each token lots
# conduct stemming for each remaining token lot
# lowercase each token of
# lowercase each token new
# conduct stemming for each remaining token new
# lowercase each token people
# conduct stemming for each remaining token peopl
# lowercase each token registered
# conduct stemming for each remaining token regist
# lowercase each token in
# lowercase each token your
# lowercase each token area
# conduct stemming for each remaining token area
# lowercase each token .
# lowercase each token reply
# conduct stemming for each remaining token repli
# lowercase each token date
# conduct stemming for each remaining token date
# lowercase each token to
# lowercase each token start
# conduct stemming for each remaining token start
# lowercase each token now
# lowercase each token !
# lowercase each token 18
# conduct stemming for each remaining token 18
# lowercase each token only
# lowercase each token www.flirtparty.us
# conduct stemming for each remaining token www.flirtparty.u
# lowercase each token replys150
# conduct stemming for each remaining token replys150
# tokenize each SMS text ['I', 'come', 'n', 'pick', 'ü', 'up', '...', 'Come', 'out', 'immediately', 'aft', 'ur', 'lesson', '...']
# lowercase each token i
# lowercase each token come
# conduct stemming for each remaining token come
# lowercase each token n
# conduct stemming for each remaining token n
# lowercase each token pick
# conduct stemming for each remaining token pick
# lowercase each token ü
# conduct stemming for each remaining token ü
# lowercase each token up
# lowercase each token ...
# conduct stemming for each remaining token ...
# lowercase each token come
# conduct stemming for each remaining token come
# lowercase each token out
# lowercase each token immediately
# conduct stemming for each remaining token immedi
# lowercase each token aft
# conduct stemming for each remaining token aft
# lowercase each token ur
# conduct stemming for each remaining token ur
# lowercase each token lesson
# conduct stemming for each remaining token lesson
# lowercase each token ...
# conduct stemming for each remaining token ...
# tokenize each SMS text ['You', 'have', '1', 'new', 'message', '.', 'Please', 'call', '08718738034', '.']
# lowercase each token you
# lowercase each token have
# lowercase each token 1
# conduct stemming for each remaining token 1
# lowercase each token new
# conduct stemming for each remaining token new
# lowercase each token message
# conduct stemming for each remaining token messag
# lowercase each token .
# lowercase each token please
# conduct stemming for each remaining token pleas
# lowercase each token call
# conduct stemming for each remaining token call
# lowercase each token 08718738034
# conduct stemming for each remaining token 08718738034
# lowercase each token .
# tokenize each SMS text ['I', '‘', 'm', 'going', 'to', 'try', 'for', '2', 'months', 'ha', 'ha', 'only', 'joking']
# lowercase each token i
# lowercase each token ‘
# conduct stemming for each remaining token ‘
# lowercase each token m
# lowercase each token going
# conduct stemming for each remaining token go
# lowercase each token to
# lowercase each token try
# conduct stemming for each remaining token tri
# lowercase each token for
# lowercase each token 2
# conduct stemming for each remaining token 2
# lowercase each token months
# conduct stemming for each remaining token month
# lowercase each token ha
# conduct stemming for each remaining token ha
# lowercase each token ha
# conduct stemming for each remaining token ha
# lowercase each token only
# lowercase each token joking
# conduct stemming for each remaining token joke
# tokenize each SMS text ['Well', 'done', 'ENGLAND', '!', 'Get', 'the', 'official', 'poly', 'ringtone', 'or', 'colour', 'flag', 'on', 'yer', 'mobile', '!', 'text', 'TONE', 'or', 'FLAG', 'to', '84199', 'NOW', '!', 'Opt-out', 'txt', 'ENG', 'STOP', '.', 'Box39822', 'W111WX', '£1.50']
# lowercase each token well
# conduct stemming for each remaining token well
# lowercase each token done
# conduct stemming for each remaining token done
# lowercase each token england
# conduct stemming for each remaining token england
# lowercase each token !
# lowercase each token get
# conduct stemming for each remaining token get
# lowercase each token the
# lowercase each token official
# conduct stemming for each remaining token offici
# lowercase each token poly
# conduct stemming for each remaining token poli
# lowercase each token ringtone
# conduct stemming for each remaining token rington
# lowercase each token or
# lowercase each token colour
# conduct stemming for each remaining token colour
# lowercase each token flag
# conduct stemming for each remaining token flag
# lowercase each token on
# lowercase each token yer
# conduct stemming for each remaining token yer
# lowercase each token mobile
# conduct stemming for each remaining token mobil
# lowercase each token !
# lowercase each token text
# ...
# conduct stemming for each remaining token app
# lowercase each token for
# lowercase each token your
# lowercase each token phone
# conduct stemming for each remaining token phone
# lowercase each token ,
# lowercase each token eh
# conduct stemming for each remaining token eh
# lowercase each token ?
# lowercase each token will
# lowercase each token you
# lowercase each token go
# conduct stemming for each remaining token go
# lowercase each token to
# lowercase each token the
# lowercase each token net
# conduct stemming for each remaining token net
# lowercase each token cafe
# conduct stemming for each remaining token cafe
# lowercase each token ?
# lowercase each token did
# lowercase each token you
# lowercase each token take
# conduct stemming for each remaining token take
# lowercase each token that
# lowercase each token job
# conduct stemming for each remaining token job
# lowercase each token ?
# lowercase each token geeee
# conduct stemming for each remaining token geeee
# lowercase each token i
# lowercase each token need
# conduct stemming for each remaining token need
# lowercase each token you
# lowercase each token babe
# conduct stemming for each remaining token babe
# lowercase each token .
# lowercase each token i
# lowercase each token crave
# conduct stemming for each remaining token crave
# lowercase each token to
# lowercase each token see
# conduct stemming for each remaining token see
# lowercase each token you
# lowercase each token ...
# conduct stemming for each remaining token ...
# tokenize each SMS text ['Ur', 'ringtone', 'service', 'has', 'changed', '!', '25', 'Free', 'credits', '!', 'Go', 'to', 'club4mobiles.com', 'to', 'choose', 'content', 'now', '!', 'Stop', '?', 'txt', 'CLUB', 'STOP', 'to', '87070', '.', '150p/wk', 'Club4', 'PO', 'Box1146', 'MK45', '2WT']
# lowercase each token ur
# conduct stemming for each remaining token ur
# lowercase each token ringtone
# conduct stemming for each remaining token rington
# lowercase each token service
# conduct stemming for each remaining token servic
# lowercase each token has
# lowercase each token changed
# conduct stemming for each remaining token chang
# lowercase each token !
# lowercase each token 25
# conduct stemming for each remaining token 25
# lowercase each token free
# conduct stemming for each remaining token free
# lowercase each token credits
# conduct stemming for each remaining token credit
# lowercase each token !
# lowercase each token go
# conduct stemming for each remaining token go
# lowercase each token to
# lowercase each token club4mobiles.com
# conduct stemming for each remaining token club4mobiles.com
# lowercase each token to
# lowercase each token choose
# conduct stemming for each remaining token choos
# lowercase each token content
# conduct stemming for each remaining token content
# lowercase each token now
# lowercase each token !
# lowercase each token stop
# conduct stemming for each remaining token stop
# lowercase each token ?
# lowercase each token txt
# conduct stemming for each remaining token txt
# lowercase each token club
# conduct stemming for each remaining token club
# lowercase each token stop
# conduct stemming for each remaining token stop
# lowercase each token to
# lowercase each token 87070
# conduct stemming for each remaining token 87070
# lowercase each token .
# lowercase each token 150p/wk
# conduct stemming for each remaining token 150p/wk
# lowercase each token club4
# conduct stemming for each remaining token club4
# lowercase each token po
# conduct stemming for each remaining token po
# lowercase each token box1146
# conduct stemming for each remaining token box1146
# lowercase each token mk45
# conduct stemming for each remaining token mk45
# lowercase each token 2wt
# conduct stemming for each remaining token 2wt
# tokenize each SMS text ['He', 'is', 'impossible', 'to', 'argue', 'with', 'and', 'he', 'always', 'treats', 'me', 'like', 'his', 'sub', ',', 'like', 'he', 'never', 'released', 'me', '...', 'Which', 'he', 'did', 'and', 'I', 'will', 'remind', 'him', 'of', 'that', 'if', 'necessary']
# lowercase each token he
# lowercase each token is
# lowercase each token impossible
# conduct stemming for each remaining token imposs
# lowercase each token to
# lowercase each token argue
# conduct stemming for each remaining token argu
# lowercase each token with
# lowercase each token and
# lowercase each token he
# lowercase each token always
# conduct stemming for each remaining token alway
# lowercase each token treats
# conduct stemming for each remaining token treat
# lowercase each token me
# lowercase each token like
# conduct stemming for each remaining token like
# lowercase each token his
# lowercase each token sub
# conduct stemming for each remaining token sub
# lowercase each token ,
# lowercase each token like
# conduct stemming for each remaining token like
# lowercase each token he
# lowercase each token never
# conduct stemming for each remaining token never
# lowercase each token released
# conduct stemming for each remaining token releas
# lowercase each token me
# lowercase each token ...
# conduct stemming for each remaining token ...
# lowercase each token which
# lowercase each token he
# lowercase each token did
# lowercase each token and
# lowercase each token i
# lowercase each token will
# lowercase each token remind
# conduct stemming for each remaining token remind
# lowercase each token him
# lowercase each token of
# lowercase each token that
# lowercase each token if
# lowercase each token necessary
# conduct stemming for each remaining token necessari
# tokenize each SMS text ['Hiya', ',', 'probably', 'coming', 'home', '*', 'weekend', 'after', 'next']
# lowercase each token hiya
# conduct stemming for each remaining token hiya
# lowercase each token ,
# lowercase each token probably
# conduct stemming for each remaining token probabl
# lowercase each token coming
# conduct stemming for each remaining token come
# lowercase each token home
# conduct stemming for each remaining token home
# lowercase each token *
# lowercase each token weekend
# conduct stemming for each remaining token weekend
# lowercase each token after
# lowercase each token next
# conduct stemming for each remaining token next
# tokenize each SMS text ['No', 'objection', '.', 'My', 'bf', 'not', 'coming', '.']
# lowercase each token no
# lowercase each token objection
# conduct stemming for each remaining token object
# lowercase each token .
# lowercase each token my
# lowercase each token bf
# conduct stemming for each remaining token bf
# lowercase each token not
# lowercase each token coming
# conduct stemming for each remaining token come
# lowercase each token .
# tokenize each SMS text ['But', 'I', "'m", 'on', 'a', 'diet', '.', 'And', 'I', 'ate', '1', 'too', 'many', 'slices', 'of', 'pizza', 'yesterday', '.', 'Ugh', 'I', "'m", 'ALWAYS', 'on', 'a', 'diet', '.']
# lowercase each token but
# lowercase each token i
# lowercase each token 'm
# conduct stemming for each remaining token 'm
# lowercase each token on
# lowercase each token a
# lowercase each token diet
# conduct stemming for each remaining token diet
# lowercase each token .
# lowercase each token and
# lowercase each token i
# lowercase each token ate
# conduct stemming for each remaining token ate
# lowercase each token 1
# conduct stemming for each remaining token 1
# lowercase each token too
# lowercase each token many
# conduct stemming for each remaining token mani
# lowercase each token slices
# conduct stemming for each remaining token slice
# lowercase each token of
# lowercase each token pizza
# conduct stemming for each remaining token pizza
# lowercase each token yesterday
# conduct stemming for each remaining token yesterday
# lowercase each token .
# lowercase each token ugh
# conduct stemming for each remaining token ugh
# lowercase each token i
# lowercase each token 'm
# conduct stemming for each remaining token 'm
# lowercase each token always
# conduct stemming for each remaining token alway
# lowercase each token on
# lowercase each token a
# lowercase each token diet
# conduct stemming for each remaining token diet
# lowercase each token .
# tokenize each SMS text ['Just', 'hopeing', 'that', 'wasn', '‘', 't', 'too', 'pissed', 'up', 'to', 'remember', 'and', 'has', 'gone', 'off', 'to', 'his', 'sisters', 'or', 'something', '!']
# lowercase each token just
# lowercase each token hopeing
# conduct stemming for each remaining token hope
# lowercase each token that
# lowercase each token wasn
# lowercase each token ‘
# conduct stemming for each remaining token ‘
# lowercase each token t
# lowercase each token too
# lowercase each token pissed
# conduct stemming for each remaining token piss
# lowercase each token up
# lowercase each token to
# lowercase each token remember
# conduct stemming for each remaining token rememb
# lowercase each token and
# lowercase each token has
# lowercase each token gone
# conduct stemming for each remaining token gone
# lowercase each token off
# lowercase each token to
# lowercase each token his
# lowercase each token sisters
# conduct stemming for each remaining token sister
# lowercase each token or
# lowercase each token something
# conduct stemming for each remaining token someth
# lowercase each token !
# tokenize each SMS text ['Sorry', 'im', 'getting', 'up', 'now', ',', 'feel', 'really', 'bad-', 'totally', 'rejected', 'that', 'kinda', 'me', 'thing', '.']
# lowercase each token sorry
# conduct stemming for each remaining token sorri
# lowercase each token im
# conduct stemming for each remaining token im
# lowercase each token getting
# conduct stemming for each remaining token get
# lowercase each token up
# lowercase each token now
# lowercase each token ,
# lowercase each token feel
# conduct stemming for each remaining token feel
# lowercase each token really
# conduct stemming for each remaining token realli
# lowercase each token bad-
# conduct stemming for each remaining token bad-
# lowercase each token totally
# conduct stemming for each remaining token total
# lowercase each token rejected
# conduct stemming for each remaining token reject
# lowercase each token that
# lowercase each token kinda
# conduct stemming for each remaining token kinda
# lowercase each token me
# lowercase each token thing
# conduct stemming for each remaining token thing
# lowercase each token .
# tokenize each SMS text ['Sac', 'will', 'score', 'big', 'hundred.he', 'is', 'set', 'batsman', ':', '-', ')']
# lowercase each token sac
# conduct stemming for each remaining token sac
# lowercase each token will
# lowercase each token score
# conduct stemming for each remaining token score
# lowercase each token big
# conduct stemming for each remaining token big
# lowercase each token hundred.he
# conduct stemming for each remaining token hundred.h
# lowercase each token is
# lowercase each token set
# conduct stemming for each remaining token set
# lowercase each token batsman
# conduct stemming for each remaining token batsman
# lowercase each token :
# lowercase each token -
# lowercase each token )
# tokenize each SMS text ['Hurry', 'up', ',', 'I', "'ve", 'been', 'weed-deficient', 'for', 'like', 'three', 'days']
# lowercase each token hurry
# conduct stemming for each remaining token hurri
# lowercase each token up
# lowercase each token ,
# lowercase each token i
# lowercase each token 've
# conduct stemming for each remaining token 've
# lowercase each token been
# lowercase each token weed-deficient
# conduct stemming for each remaining token weed-defici
# lowercase each token for
# lowercase each token like
# conduct stemming for each remaining token like
# lowercase each token three
# conduct stemming for each remaining token three
# lowercase each token days
# conduct stemming for each remaining token day
# tokenize each SMS text ['We', 'know', 'someone', 'who', 'you', 'know', 'that', 'fancies', 'you', '.', 'Call', '09058097218', 'to', 'find', 'out', 'who', '.', 'POBox', '6', ',', 'LS15HB', '150p']
# lowercase each token we
# lowercase each token know
# conduct stemming for each remaining token know
# lowercase each token someone
# conduct stemming for each remaining token someon
# lowercase each token who
# lowercase each token you
# lowercase each token know
# conduct stemming for each remaining token know
# lowercase each token that
# lowercase each token fancies
# conduct stemming for each remaining token fanci
# lowercase each token you
# lowercase each token .
# lowercase each token call
# conduct stemming for each remaining token call
# lowercase each token 09058097218
# conduct stemming for each remaining token 09058097218
# lowercase each token to
# lowercase each token find
# conduct stemming for each remaining token find
# lowercase each token out
# lowercase each token who
# lowercase each token .
# lowercase each token pobox
# conduct stemming for each remaining token pobox
# lowercase each token 6
# conduct stemming for each remaining token 6
# lowercase each token ,
# lowercase each token ls15hb
# conduct stemming for each remaining token ls15hb
# lowercase each token 150p
# conduct stemming for each remaining token 150p
# tokenize each SMS text ['Refused', 'a', 'loan', '?', 'Secured', 'or', 'Unsecured', '?', 'Ca', "n't", 'get', 'credit', '?', 'Call', 'free', 'now', '0800', '195', '6669', 'or', 'text', 'back', "'help", "'", '&', 'we', 'will', '!']
# lowercase each token refused
# conduct stemming for each remaining token refus
# lowercase each token a
# lowercase each token loan
# conduct stemming for each remaining token loan
# lowercase each token ?
# lowercase each token secured
# conduct stemming for each remaining token secur
# lowercase each token or
# lowercase each token unsecured
# conduct stemming for each remaining token unsecur
# lowercase each token ?
# lowercase each token ca
# conduct stemming for each remaining token ca
# lowercase each token n't
# conduct stemming for each remaining token n't
# lowercase each token get
# conduct stemming for each remaining token get
# lowercase each token credit
# conduct stemming for each remaining token credit
# lowercase each token ?
# lowercase each token call
# conduct stemming for each remaining token call
# lowercase each token free
# conduct stemming for each remaining token free
# lowercase each token now
# lowercase each token 0800
# conduct stemming for each remaining token 0800
# lowercase each token 195
# conduct stemming for each remaining token 195
# lowercase each token 6669
# conduct stemming for each remaining token 6669
# lowercase each token or
# lowercase each token text
# conduct stemming for each remaining token text
# lowercase each token back
# conduct stemming for each remaining token back
# lowercase each token 'help
# conduct stemming for each remaining token 'help
# lowercase each token '
# lowercase each token &
# lowercase each token we
# lowercase each token will
# lowercase each token !
# tokenize each SMS text ['Aight', 'no', 'rush', ',', 'I', "'ll", 'ask', 'jay']
# lowercase each token aight
# conduct stemming for each remaining token aight
# lowercase each token no
# lowercase each token rush
# conduct stemming for each remaining token rush
# lowercase each token ,
# lowercase each token i
# lowercase each token 'll
# conduct stemming for each remaining token 'll
# lowercase each token ask
# conduct stemming for each remaining token ask
# lowercase each token jay
# conduct stemming for each remaining token jay
#
# --- First 10 Preprocessed SMS Messages (spam-train.csv) ---
# (0) Msg 1: yep pretti sculptur
# (0) Msg 2: leav
# (0) Msg 3: take exam march 3
# (1) Msg 4: want 750 anytim network min 150 text new video phone five pound per week call 08000776320 repli deliveri tomorrow
# (0) Msg 5: boy made fun today ok problem sent one messag fun
# (0) Msg 6: ok .... take care.umma ...
# (0) Msg 7: well uv caus mutat sunscreen like essenti theseday
# (1) Msg 8: free top rington -sub weekli ringtone-get 1st week free-send subpoli 81618- 3 per week-stop sms-08718727870
# (0) Msg 9: hey gal ... u wan na meet 4 dinner nìte
# (0) Msg 10: n't come home class right need work shower
#
# --- First 10 Preprocessed SMS Messages (spam-test.csv) ---
# (0) Msg 1: sorri da thought call lot time lil busy.i call noon ..
# (1) Msg 2: urgent mobil award £2,000 bonu caller prize 1/08/03 2nd attempt contact call 0871-4719-523 box95qu bt nation rate
# (0) Msg 3: u call ...
# (0) Msg 4: wait 4 u lor ... need 2 feel bad lar ...
# (1) Msg 5: win winner mr. t. foley ipod excit prize soon keep eye ur mobil visit www.win-82050.co.uk
# (0) Msg 6: cant wait see photo use
# (0) Msg 7: ya nice .be readi thursday
# (0) Msg 8: check nuerologist
# (0) Msg 9: life all mone eppolum oru pole allalo
# (0) Msg 10: oki ...

# %% [markdown]
# ## Part 2.2: Convert Text Data with TF-IDF (1.5 Point)
# After data preprocessing, the next step is to convert each SMS message into a numerical vector using TF-IDF. We also provide some example code to help you get started, so you only need to complete the code under the "TODO" comments.
#
# For this section, your code should convert each SMS text into a TF-IDF vector so that the input features will become a large matrix of `(n_msg, n_features)`, where `n_msg` is the total number of SMS messages in the dataset, and `n_features` is the total number of features (i.e., the number of top tokens used for building the TF-IDF vectors).
#
# When completing the code, please notice that we should fit the TF-IDF vectorizer using data from `spam-train.csv` and then use the vectorizer to convert data from both `spam-train.csv` and `spam-test.csv`. This is because some tokens might only appear in the test set and including them to build the TF-IDF vectors would cause potential [data leakage](https://machinelearningmastery.com/data-leakage-machine-learning/).

# %%
# we can apply TfidfVectorizer function to extract TF-IDF vectors for each message
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_transformer = TfidfVectorizer(max_features=500)

# TODO: replace the question marks '?' with the correct variables you created in Section 2.1
tfidf_transformer.fit(new_train_msgs)
train_features = tfidf_transformer.transform(new_train_msgs).toarray()
tfidf_transformer.fit(new_test_msgs)
test_features = tfidf_transformer.transform(new_test_msgs).toarray()

# --- Optional: Print the resulting shapes for verification ---
print(f"✅ TF-IDF Vectorization Complete.")
print(f"Training Feature Matrix Shape (n_msg, n_features): {train_features.shape}")
print(f"Testing Feature Matrix Shape (n_msg, n_features): {test_features.shape}")
# Out:
# ✅ TF-IDF Vectorization Complete.
# Training Feature Matrix Shape (n_msg, n_features): (1600, 500)
# Testing Feature Matrix Shape (n_msg, n_features): (400, 500)

# %% [markdown]
# ## Part 3: Apply Machine Learning to Combat Spam Messages (3 Points)
# In this section, you need to train a Naive Bayes classifier to predict whether a given SMS message is a spam message or not. Specifically, you need to use the TF-IDF vectors of the training dataset (`train_features`) to train the classifier and use the TF-IDF vectors of the test dataset (`test_features`) for prediction. Once the prediction is finished, please report the F1 score and AUC-ROC on the test dataset for the Naive Bayes classifier.
#
# For your reference, we have provided example code to train a logistic regression classifier using the TF-IDF vectors of the training dataset and calculate the classifier's F1  and AUC-ROC scores on the test dataset. In addition, we also show how you can extract each token's coefficient from the trained logistic regression model (this part will be relevant to the extra lab assignment).

# %%
"""
In this code cell, we provide example code on how to evaluate a logistic regression
classifier's performance in identifying spam messages;
we also provide code on extracting the logistic regression coefficients for
different tokens, which could be helpful for your extra lab assignment
"""
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, roc_auc_score
import pandas as pd


log_clf = LogisticRegression()
log_clf.fit(train_features, spam_train['label'])        # fit the model
log_clf_pred = log_clf.predict(test_features)           # make predictions
log_clf_score = log_clf.predict_proba(test_features)    # get prediction scores

## F1 score
log_clf_f1 = f1_score(spam_test['label'], log_clf_pred)
print('Prediction F1: {:.4f}'.format(log_clf_f1))

## AUC-ROC
log_clf_auc = roc_auc_score(spam_test['label'], log_clf_score[:, 1])
print('AUC-ROC : {:.4f}'.format(log_clf_auc))
print()

# you can use the code below to extract logistic regression's features and their
# coefficients; specifically, feature_names_in_ will return all the input features,
# and coef_ will return all the features' estimated coefficients
log_clf_coef = pd.DataFrame({
    'Feature Name': tfidf_transformer.get_feature_names_out(),
    'Coefficient': log_clf.coef_[0]
})
print(log_clf_coef)

from sklearn.naive_bayes import MultinomialNB
nb_clf = MultinomialNB()
nb_clf.fit(train_features, spam_train['label'])

# 2. Make Predictions on the Test Set
# Predict the class label (0 or 1)
nb_clf_pred = nb_clf.predict(test_features)
# Predict the probability scores (needed for AUC-ROC)
nb_clf_score = nb_clf.predict_proba(test_features)
## F1 score
# The F1 score is the harmonic mean of precision and recall, useful for imbalanced datasets like spam
nb_clf_f1 = f1_score(spam_test['label'], nb_clf_pred)
print('✨ Naive Bayes Classifier Performance ✨')
print('Prediction F1: {:.4f}'.format(nb_clf_f1))

## AUC-ROC
# The Area Under the Receiver Operating Characteristic Curve measures the classifier's ability
# to distinguish between classes across all possible classification thresholds.
# We use the probability for the positive class (column index 1).
nb_clf_auc = roc_auc_score(spam_test['label'], nb_clf_score[:, 1])
print('AUC-ROC : {:.4f}'.format(nb_clf_auc))
print()

# --- Optional: Extracting Coefficients (Coefficients for Naive Bayes) ---
# For Naive Bayes, the 'coefficients' are the logarithm of the feature probabilities,
# stored in the `feature_log_prob_` attribute.

# NOTE: tfidf_transformer must be available from the previous step (Section 2)
nb_clf_coef = pd.DataFrame({
    'Feature Name': tfidf_transformer.get_feature_names_out(),
    # We look at the log probability for the spam class (index 1)
    'Log Probability (Spam)': nb_clf.feature_log_prob_[1]
})

# Sort by log probability to see the most spam-indicative words
nb_clf_coef_sorted = nb_clf_coef.sort_values(by='Log Probability (Spam)', ascending=False).head(10)

print('--- Top 10 Naive Bayes Spam-Indicative Features (Log Probabilities) ---')
print(nb_clf_coef_sorted)
# Out:
# Prediction F1: 0.0000
# AUC-ROC : 0.6308
#
#     Feature Name  Coefficient
# 0            000     0.799625
# 1             08     0.752851
# 2           0800     0.569546
# 3    08706091795     1.139163
# 4    09050090044     0.712506
# ..           ...          ...
# 495         yeah    -0.141890
# 496         year    -0.300203
# 497    yesterday    -0.357362
# 498          yet     0.201907
# 499     yogasana    -0.277310
#
# [500 rows x 2 columns]
# ✨ Naive Bayes Classifier Performance ✨
# Prediction F1: 0.2366
# AUC-ROC : 0.6676
#
# --- Top 10 Naive Bayes Spam-Indicative Features (Log Probabilities) ---
#     Feature Name  Log Probability (Spam)
# 70           buy               -3.972606
# 160         fine               -4.163558
# 445     tomorrow               -4.259424
# 415          sub               -4.569025
# 269         meet               -4.624674
# 488        would               -4.733582
# 448         true               -4.816160
# 404        spoke               -4.864035
# 87        church               -4.879798
# 265          may               -4.944197

# %%
"""
In this code cell, please write your own code on evaluating a naive bayes
classifier's performance in identifying spam messages
"""
